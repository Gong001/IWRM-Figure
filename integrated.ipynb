# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse, Polygon
import seaborn as sns
import matplotlib.ticker as mtick
plt.rcParams['figure.dpi'] = 100

# %%
df2 = pd.read_csv('Continent.csv').sort_values("Number", ascending=False)

# %%
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(8,3),dpi=300)
# read data dataset
# Plot the total number
sns.set_color_codes("pastel")
sns.barplot(x="Number", y="Continent", data=df2,label='Total',color="r",hatch="",edgecolor='black',)
# Plot the before 2011
sns.set_color_codes("muted")
sns.barplot(x="Before 2011", y="Continent", data=df2,label="Published before 2011\n(Not including 2011)", 
            color="plum",hatch="//",edgecolor='k',)
# Add a legend and informative axis label
ax.legend(ncol=2, loc=4, frameon=True,fontsize=8)
ax.set(xlim=(0, 400))
ax.set_ylabel('Research Continents', color='k', fontsize=13)
ax.set_xlabel('Number of publication', color='k', fontsize=13)
sns.despine(left=True, bottom=True)

plt.show()

# %%
import pandas as pd 
from matplotlib import pyplot as plt 
  
# Read CSV into pandas 
df1 = pd.read_csv('integrated.csv').head(17)
df=df1.sort_values('Total',ascending=True)
issues = ['Water and land-related issues','Ecological environment and climate change','Stakeholders and policy',
          'National and international organizations','Economy benefits related issues','Water supply and demand',
          'Waste water-related issues','Water quality and quantity','Legal and regulatory framworks',
          'Groundwater and surface water','Water and public participation-related issues','Right to water',
          'Race and gender','Rural and urban']

f, ax = plt.subplots(figsize=(8,6),dpi=800)
ax.set_title('Issues considered by IWRM(Number)',fontsize=20)
ax.set_xlabel('Number of publication', color='k', fontsize=13)
ax.set_ylabel('Countries', color='k', fontsize=13)
ax.barh(df['Countries'],df[issues[0]],alpha=0.7,edgecolor='k',facecolor='pink')
ax.barh(df['Countries'],df[issues[1]],alpha=0.7,edgecolor='k',facecolor='r',left = df[issues[0]])
ax.barh(df['Countries'],df[issues[2]],alpha=0.7,edgecolor='k',facecolor='coral',hatch="",
         left = (df[issues[0]]+df[issues[1]]))
ax.barh(df['Countries'],df[issues[3]],alpha=0.7,edgecolor='k',facecolor='chocolate',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]))
ax.barh(df['Countries'],df[issues[4]],alpha=0.7,edgecolor='k',facecolor='orange',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]))
ax.barh(df['Countries'],df[issues[5]],alpha=0.7,edgecolor='k',facecolor='bisque',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]))
ax.barh(df['Countries'],df[issues[6]],alpha=0.7,edgecolor='k',facecolor='white',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]))
ax.barh(df['Countries'],df[issues[7]],alpha=0.7,edgecolor='k',facecolor='yellow',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]))
ax.barh(df['Countries'],df[issues[8]],alpha=0.7,edgecolor='k',facecolor='yellowgreen',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]))
ax.barh(df['Countries'],df[issues[9]],alpha=0.7,edgecolor='k',facecolor='lawngreen',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]+df[issues[8]]))
ax.barh(df['Countries'],df[issues[10]],alpha=0.7,edgecolor='k',facecolor='darkgreen',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]+df[issues[8]]+df[issues[9]]))
ax.barh(df['Countries'],df[issues[11]],alpha=0.7,edgecolor='k',facecolor='teal',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]+df[issues[8]]+df[issues[9]]+df[issues[10]]))
ax.barh(df['Countries'],df[issues[12]],alpha=0.7,edgecolor='k',facecolor='cyan',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]+df[issues[8]]+df[issues[9]]+df[issues[10]]+df[issues[11]]))
ax.barh(df['Countries'],df[issues[13]],alpha=0.7,edgecolor='k',facecolor='lightblue',
         left = (df[issues[0]]+df[issues[1]]+df[issues[2]]+df[issues[3]]+df[issues[4]]+df[issues[5]]+df[issues[6]]
                +df[issues[7]]+df[issues[8]]+df[issues[9]]+df[issues[10]]+df[issues[11]]+df[issues[12]]))


sns.despine(left=True, bottom=True)

ax.grid(axis='y',color='k',ls='--')
ax.set(xlim=(0, 100))
ax.legend(labels = ['Water and land-related issues','Ecological environment and climate change','Stakeholders and policy',
          'National and international organizations','Economy benefits related issues','Water supply and demand',
          'Waste water-related issues','Water quality and quantity','Legal and regulatory framworks',
          'Groundwater and surface water','Water and public participation-related issues','Right to water',
          'Race and gender','Rural and urban'],loc=4,ncol=1,frameon=True,fontsize=6)

plt.show()

# %%
import pandas as pd 
from matplotlib import pyplot as plt 
  
# Read CSV into pandas 
df1 = pd.read_csv('integrated.csv').head(17)
df=df1.sort_values('Total',ascending=True)
issues = ['Water and land-related issues','Ecological environment and climate change','Stakeholders and policy',
          'National and international organizations','Economy benefits related issues','Water supply and demand',
          'Waste water-related issues','Water quality and quantity','Legal and regulatory framworks',
          'Groundwater and surface water','Water and public participation-related issues','Right to water',
          'Race and gender','Rural and urban','Total']

f, ax = plt.subplots(figsize=(8,6),dpi=800)
ax.set_title('Issues considered by IWRM (Percentage)   ',fontsize=20)
ax.set_xlabel('Percentage   ', color='k', fontsize=13)
ax.set_ylabel('Countries', color='k', fontsize=13)
ax.barh(df['Countries'],df[issues[0]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='pink')
ax.barh(df['Countries'],df[issues[1]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='r',
                           left = df[issues[0]]/df[issues[14]])
ax.barh(df['Countries'],df[issues[2]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='coral',hatch="",
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[3]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='chocolate',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[4]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='orange',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+df[issues[3]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[5]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='bisque',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]
                 +df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[6]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='white',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[7]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='yellow',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[8]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='yellowgreen',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[9]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='lawngreen',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]+df[issues[8]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[10]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='darkgreen',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]+df[issues[8]]/df[issues[14]]+df[issues[9]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[11]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='teal',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]+df[issues[8]]/df[issues[14]]+df[issues[9]]/df[issues[14]]+
                 df[issues[10]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[12]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='cyan',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]+df[issues[8]]/df[issues[14]]+df[issues[9]]/df[issues[14]]+
                 df[issues[10]]/df[issues[14]]+df[issues[11]]/df[issues[14]]))
ax.barh(df['Countries'],df[issues[13]]/df[issues[14]],alpha=0.7,edgecolor='k',facecolor='lightblue',
         left = (df[issues[0]]/df[issues[14]]+df[issues[1]]/df[issues[14]]+df[issues[2]]/df[issues[14]]+
                 df[issues[3]]/df[issues[14]]+df[issues[4]]/df[issues[14]]+df[issues[5]]/df[issues[14]]+
                 df[issues[6]]/df[issues[14]]
                +df[issues[7]]/df[issues[14]]+df[issues[8]]/df[issues[14]]+df[issues[9]]/df[issues[14]]+
                 df[issues[10]]/df[issues[14]]+df[issues[11]]/df[issues[14]]+df[issues[12]]/df[issues[14]]))


sns.despine(left=True, bottom=True)

ax.grid(axis='y',color='k',ls='--')
ax.set(xlim=(0,1))
box = ax.get_position()
ax.set_position([box.x0,box.y0,box.width,box.height*0.8])
ax.legend(labels = ['Water and land-related issues','Ecological environment and climate change','Stakeholders and policy',
          'National and international organizations','Economy benefits related issues','Water supply and demand',
          'Waste water-related issues','Water quality and quantity','Legal and regulatory framworks',
          'Groundwater and surface water','Water and public participation-related issues','Right to water',
          'Race and gender','Rural and urban'],loc='lower center',bbox_to_anchor=(0.53,-0.33),
          ncol=3,frameon=False,fontsize=6)

ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))
box = ax.get_position()
ax.set_position
plt.show()
